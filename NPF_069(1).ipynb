# %% [markdown]
# # Предсказывание в ритейл
# ## Подготовка данных

# %%
# !pip install catboost
# !pip install optuna

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 12, 8
plt.rcParams['font.size'] = 12
sns.set_style('darkgrid')

from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Загрузим данные:

# %%
data_train = pd.read_csv('train.csv')
data_train
# Out:
#           period_dt  location_id  product_id  demand  PROMO1_FLAG  \
# 0        2019-12-30        425.0     22939.0     NaN          0.0
# 1        2019-12-30        525.0     22939.0     NaN          0.0
# 2        2019-12-30        557.0     22939.0     NaN          0.0
# 3        2019-12-30        562.0     22939.0     NaN          0.0
# 4        2019-12-30        637.0     22939.0     NaN          0.0
# ...             ...          ...         ...     ...          ...
# 2333098  2019-12-30          NaN         NaN     NaN          1.0
# 2333099  2019-12-30          NaN         NaN     NaN          1.0
# 2333100  2019-12-30          NaN         NaN     NaN          1.0
# 2333101  2019-12-30          NaN         NaN     NaN          1.0
# 2333102  2019-12-30          NaN         NaN     NaN          1.0
#
#          PROMO2_FLAG  PRICE_REGULAR  PRICE_AFTER_DISC  NUM_CONSULTANT  \
# 0                0.0         3649.0           2736.75             0.0
# 1                0.0         3649.0           2371.85             0.0
# 2                0.0         3649.0           2736.75             0.0
# 3                0.0         3649.0           2736.75             0.0
# 4                0.0         3649.0           3101.65             0.0
# ...              ...            ...               ...             ...
# 2333098          0.0         3949.0           2369.40             0.0
# 2333099          0.0            NaN               NaN             0.0
# 2333100          0.0            NaN               NaN             0.0
# 2333101          0.0            NaN               NaN             0.0
# 2333102          0.0         2750.0           1650.00             0.0
#
#          AUTORIZATION_FLAG       id
# 0                      0.0        1
# 1                      1.0        3
# 2                      1.0        5
# 3                      0.0        7
# 4                      0.0        9
# ...                    ...      ...
# 2333098                1.0  2337654
# 2333099                0.0  2337655
# 2333100                0.0  2337656
# 2333101                0.0  2337657
# 2333102                1.0  2337658
#
# [2333103 rows x 11 columns]

# %%
data_test = pd.read_csv('test.csv')
data_test
# Out:
#      product_id  location_id   period_dt      id
# 0         22939         1162  2019-12-30      16
# 1         23162         1162  2019-12-30    7867
# 2         23163         1162  2019-12-16    8667
# 3         23632          798  2019-12-23   14835
# 4         23633         1347  2019-12-30   14959
# ..          ...          ...         ...     ...
# 588      139157         1326  2019-12-16  203996
# 589      139157         1347  2019-12-09  203997
# 590      148040          425  2019-12-09  204035
# 591      148040          525  2019-12-09  204037
# 592      148683          525  2019-12-30  204065
#
# [593 rows x 4 columns]

# %% [markdown]
# Подготовим данные

# %%
data_train.dtypes
# Out:
# period_dt             object
# location_id          float64
# product_id           float64
# demand               float64
# PROMO1_FLAG          float64
# PROMO2_FLAG          float64
# PRICE_REGULAR        float64
# PRICE_AFTER_DISC     float64
# NUM_CONSULTANT       float64
# AUTORIZATION_FLAG    float64
# id                     int64
# dtype: object

# %%
data_test.dtypes
# Out:
# product_id      int64
# location_id     int64
# period_dt      object
# id              int64
# dtype: object

# %% [markdown]
# Видно, что необходимо конвертировать столбец period_dt к типу DATE. Сделаем специальную функцию для этого:

# %%
def convert_date_type(df):
    data = pd.to_datetime(df['period_dt'])
    df.drop(columns=['period_dt'], inplace=True)
    df['day'] = data.dt.day
    df['month'] = data.dt.month
    df['year'] = data.dt.year
    df['week_of_year'] = data.dt.weekofyear
    df['day_of_year'] = data.dt.dayofyear

# %%
convert_date_type(data_train)
convert_date_type(data_test)

# %%
data_train.dtypes
# Out:
# location_id          float64
# product_id           float64
# demand               float64
# PROMO1_FLAG          float64
# PROMO2_FLAG          float64
# PRICE_REGULAR        float64
# PRICE_AFTER_DISC     float64
# NUM_CONSULTANT       float64
# AUTORIZATION_FLAG    float64
# id                     int64
# day                    int64
# month                  int64
# year                   int64
# week_of_year           int64
# day_of_year            int64
# dtype: object

# %% [markdown]
# Посмотрим, есть ли пропуски в данных:

# %%
data_train.isna().sum()
# Out:
# location_id          2048984
# product_id           2048984
# demand               2058632
# PROMO1_FLAG             1797
# PROMO2_FLAG             1797
# PRICE_REGULAR         810628
# PRICE_AFTER_DISC      831151
# NUM_CONSULTANT          1797
# AUTORIZATION_FLAG       1797
# id                         0
# day                        0
# month                      0
# year                       0
# week_of_year               0
# day_of_year                0
# dtype: int64

# %%
def fill_bools(X):
    Y = X.copy()
    vals = {"PROMO1_FLAG": 0, "PROMO2_FLAG": 0, "NUM_CONSULTANT": 0, "AUTORIZATION_FLAG": 0} 
    return Y.fillna(value=vals)

def fill_floats(store_ids, X):
    Y = X.copy()
    for store in store_ids:
        val1 = Y.loc[Y["product_id"] == store]["PRICE_REGULAR"].mean()
        val2 = Y.loc[Y["product_id"] == store]["PRICE_AFTER_DISC"].mean()
        val3 = Y.loc[Y["product_id"] == store]["demand"].mean()
        Y.loc[(Y["product_id"] == store) & (Y["PRICE_REGULAR"].isna()), "PRICE_REGULAR"] = val1
        Y.loc[(Y["product_id"] == store) & (Y["PRICE_AFTER_DISC"].isna()), "PRICE_AFTER_DISC"] = val2
        Y.loc[(Y["product_id"] == store) & (Y["demand"].isna()), "demand"] = val3
    return Y

# %% [markdown]
# PROMO1_FLAG, PROMO2_FLAG заполним нулями, используя логику, как на семинарах, если акция не указана, скорее всего ее не было. Так же поступим с NUM_CONSULTANT. AUTORIZATION_FLAG тоже заполним 0, преполагая, что авторицазии не было. PRICE_REGULAR и PRICE_AFTER_DISC заполним средними значениями по столбцам:

# %%
dtypes_train = {"PROMO1_FLAG": np.int32, "PROMO2_FLAG": np.int32,
                                            "NUM_CONSULTANT": np.int32, "AUTORIZATION_FLAG": np.int32,
                                            "demand": np.float32, "PRICE_REGULAR": np.float32, "PRICE_AFTER_DISC": np.float32,
                                            "day": np.int32, "month": np.int32, "year": np.int32,
                                            "week_of_year": np.int32, "day_of_year": np.int32}
dtypes_test = {"day": np.int32, "month": np.int32, "year": np.int32,
                "week_of_year": np.int32, "day_of_year": np.int32,
                "location_id": np.int32, "product_id": np.int32}
dtypes_aposterior = {"location_id": np.int32, "product_id": np.int32}
data_train_clear = fill_floats(data_train.groupby("product_id").mean().index, data_train)
data_train_clear = fill_bools(data_train_clear)
data_train_clear = data_train_clear.astype(dtypes_train)
data_test_clear = data_test.astype(dtypes_test)
data_train_clear = data_train_clear.dropna()
data_train_clear = data_train_clear.astype(dtypes_aposterior)
data_train_clear = data_train_clear.drop(columns=["id"])
data_test_clear = data_test_clear.drop(columns=["id"])

# %%
data_train_clear.head()
# Out:
#    location_id  product_id    demand  PROMO1_FLAG  PROMO2_FLAG  PRICE_REGULAR  \
# 0          425       22939  0.170391            0            0         3649.0
# 1          525       22939  0.170391            0            0         3649.0
# 2          557       22939  0.170391            0            0         3649.0
# 3          562       22939  0.170391            0            0         3649.0
# 4          637       22939  0.170391            0            0         3649.0
#
#    PRICE_AFTER_DISC  NUM_CONSULTANT  AUTORIZATION_FLAG  day  month  year  \
# 0       2736.750000               0                  0   30     12  2019
# 1       2371.850098               0                  1   30     12  2019
# 2       2736.750000               0                  1   30     12  2019
# 3       2736.750000               0                  0   30     12  2019
# 4       3101.649902               0                  0   30     12  2019
#
#    week_of_year  day_of_year
# 0             1          364
# 1             1          364
# 2             1          364
# 3             1          364
# 4             1          364

# %% [markdown]
# ## Выбор признаков

# %%
#features = lagged_features(data_train, data_train['demand'], data_train['location_id'])
data_train_features = data_train_clear.copy()
data_test_features = data_test_clear.copy()

# %%
plot = sns.relplot(data=data_train_clear, x="day_of_year", y="demand", kind="line", palette="hls", height=6, aspect=2)
plot.set(xticklabels=[], title="График зависимости среднего спроса от дня в году")
plt.show()
plot = sns.relplot(data=data_train_clear, x="week_of_year", y="demand", kind="line", palette="hls", height=6, aspect=2)
plot.set(title="График зависимости среднего спроса от недели года")
plt.show()

# %%
plot = sns.relplot(data=data_train_clear, x="year", y="demand", kind="line", palette="hls", height=6, aspect=2)
plot.set(title="График зависимости среднего спроса от года")
plt.show()

# %%
plot = sns.histplot(data=data_train_clear, x="demand")
plot.set(title="Распределение demand")
plt.show()
plt.hist(np.log1p(data_train_clear["demand"]), bins=20)
plt.title("Log-распределение demand")
plt.show()

# %%
def add_high_demand(X, tres=0.6):
    Y = X.copy()
    ids = data_train_clear.groupby("week_of_year").mean()[(data_train_clear.groupby("week_of_year").mean()["demand"] > tres)].index.values
    Y["high_demand_week"] = 0
    Y["high_demand_year"] = 0
    Y.loc[Y["week_of_year"].isin(ids), "high_demand_week"] = 1
    Y.loc[Y["year"] < 2017, "high_demand_year"] = 1
    return Y

data_train_features = add_high_demand(data_train_features)
data_test_features = add_high_demand(data_test_features)
data_train_features["log_demand"] = np.log1p(data_train_clear["demand"])

# %%
data_train_features.head()
# Out:
#    location_id  product_id    demand  PROMO1_FLAG  PROMO2_FLAG  PRICE_REGULAR  \
# 0          425       22939  0.170391            0            0         3649.0
# 1          525       22939  0.170391            0            0         3649.0
# 2          557       22939  0.170391            0            0         3649.0
# 3          562       22939  0.170391            0            0         3649.0
# 4          637       22939  0.170391            0            0         3649.0
#
#    PRICE_AFTER_DISC  NUM_CONSULTANT  AUTORIZATION_FLAG  day  month  year  \
# 0       2736.750000               0                  0   30     12  2019
# 1       2371.850098               0                  1   30     12  2019
# 2       2736.750000               0                  1   30     12  2019
# 3       2736.750000               0                  0   30     12  2019
# 4       3101.649902               0                  0   30     12  2019
#
#    week_of_year  day_of_year  high_demand_week  high_demand_year  log_demand
# 0             1          364                 0                 0    0.157338
# 1             1          364                 0                 0    0.157338
# 2             1          364                 0                 0    0.157338
# 3             1          364                 0                 0    0.157338
# 4             1          364                 0                 0    0.157338

# %% [markdown]
# ## Обучение модели

# %%
y = data_train_features['log_demand']
X = data_train_features.drop(columns=["demand"])[['location_id', 'product_id', 'day_of_year', "high_demand_week", "high_demand_year"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=322)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=322)
Test = data_test_features[['location_id', 'product_id', 'day_of_year', "high_demand_week", "high_demand_year"]]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

categor = []
numer = ["location_id", "product_id", "day_of_year"]

col_transformer = ColumnTransformer([
    ("standart", StandardScaler(), numer),
    ("ohe", OneHotEncoder(drop="first", sparse=False, handle_unknown="ignore"), categor)
], remainder="passthrough", n_jobs=-1)
col_transformer.fit(X_train)

X_train = col_transformer.transform(X_train)
X_val = col_transformer.transform(X_val)
X_test = col_transformer.transform(X_test)
Test = col_transformer.transform(Test)

# %%
import optuna

def objective(trial):
    param = {
        "logging_level": "Silent",
        "random_state": 322,
        "eval_metric": "MAE",
        "n_estimators": trial.suggest_int("n_estimators", 5, 25),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 1),
        "bootstrap_type": "Bernoulli",
        "subsample": trial.suggest_float("subsample", 0.1, 1),
        "depth": trial.suggest_int("depth", 1, 15)
      }
    booster = CatBoostRegressor(**param).fit(X_train, y_train, eval_set=(X_val, y_val))
    y_pred = booster.predict(X_val)
    mae = mean_absolute_error(y_val, y_pred)
    return mae

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# {'n_estimators': 20, 'learning_rate': 0.8216148051350802, 'subsample': 0.9574480991797255, 'depth': 12}
# Out:
# [I 2022-06-16 17:27:48,629] A new study created in memory with name: no-name-5ffe30a8-75f4-4e23-8ffd-9e9340589728
# [I 2022-06-16 17:27:48,948] Trial 0 finished with value: 0.2206388784345843 and parameters: {'n_estimators': 5, 'learning_rate': 0.30729070464548075, 'subsample': 0.31548751434947836, 'depth': 11}. Best is trial 0 with value: 0.2206388784345843.
# [I 2022-06-16 17:27:49,070] Trial 1 finished with value: 0.2105428477335141 and parameters: {'n_estimators': 7, 'learning_rate': 0.5419270535696827, 'subsample': 0.3841398826080772, 'depth': 8}. Best is trial 1 with value: 0.2105428477335141.
# [I 2022-06-16 17:27:51,056] Trial 2 finished with value: 0.1992026554131499 and parameters: {'n_estimators': 18, 'learning_rate': 0.3539001240438641, 'subsample': 0.8318800883982177, 'depth': 14}. Best is trial 2 with value: 0.1992026554131499.
# [I 2022-06-16 17:27:51,684] Trial 3 finished with value: 0.2103588819420978 and parameters: {'n_estimators': 22, 'learning_rate': 0.15095553642337975, 'subsample': 0.2557587392165991, 'depth': 12}. Best is trial 2 with value: 0.1992026554131499.
# [I 2022-06-16 17:27:52,231] Trial 4 finished with value: 0.2006854958083005 and parameters: {'n_estimators': 11, 'learning_rate': 0.8518886243809976, 'subsample': 0.16718854313042747, 'depth': 13}. Best is trial 2 with value: 0.1992026554131499.
# [I 2022-06-16 17:27:52,323] Trial 5 finished with value: 0.23519553904134377 and parameters: {'n_estimators': 6, 'learning_rate': 0.25890683866144043, 'subsample': 0.5868557186612403, 'depth': 2}. Best is trial 2 with value: 0.1992026554131499.
# [I 2022-06-16 17:27:52,446] Trial 6 finished with value: 0.22597337483773663 and parameters: {'n_estimators': 15, 'learning_rate': 0.40815772480729656, 'subsample': 0.1938455745963348, 'depth': 1}. Best is trial 2 with value: 0.1992026554131499.
# [I 2022-06-16 17:27:53,116] Trial 7 finished with value: 0.19885556626449905 and parameters: {'n_estimators': 20, 'learning_rate': 0.4014403269948319, 'subsample': 0.8829736180118194, 'depth': 12}. Best is trial 7 with value: 0.19885556626449905.
# [I 2022-06-16 17:27:53,310] Trial 8 finished with value: 0.2105333431679487 and parameters: {'n_estimators': 15, 'learning_rate': 0.2662427955903243, 'subsample': 0.5644735902471643, 'depth': 8}. Best is trial 7 with value: 0.19885556626449905.
# [I 2022-06-16 17:27:53,473] Trial 9 finished with value: 0.21884920762693724 and parameters: {'n_estimators': 22, 'learning_rate': 0.3266794807406936, 'subsample': 0.3650479848291218, 'depth': 2}. Best is trial 7 with value: 0.19885556626449905.
# [I 2022-06-16 17:27:53,735] Trial 10 finished with value: 0.2013006912983106 and parameters: {'n_estimators': 24, 'learning_rate': 0.6327782714537057, 'subsample': 0.9959545886213222, 'depth': 5}. Best is trial 7 with value: 0.19885556626449905.
# [I 2022-06-16 17:27:57,140] Trial 11 finished with value: 0.2587352534577942 and parameters: {'n_estimators': 19, 'learning_rate': 0.01330029715102482, 'subsample': 0.8907815946207112, 'depth': 15}. Best is trial 7 with value: 0.19885556626449905.
# [I 2022-06-16 17:28:00,628] Trial 12 finished with value: 0.19211219225587794 and parameters: {'n_estimators': 18, 'learning_rate': 0.7131009333031977, 'subsample': 0.7782991635889493, 'depth': 15}. Best is trial 12 with value: 0.19211219225587794.
# [I 2022-06-16 17:28:00,977] Trial 13 finished with value: 0.19582980767646435 and parameters: {'n_estimators': 18, 'learning_rate': 0.7707027429638996, 'subsample': 0.7153895995452306, 'depth': 10}. Best is trial 12 with value: 0.19211219225587794.
# [I 2022-06-16 17:28:01,229] Trial 14 finished with value: 0.1993288219333574 and parameters: {'n_estimators': 12, 'learning_rate': 0.8391177592613005, 'subsample': 0.7005790485132486, 'depth': 10}. Best is trial 12 with value: 0.19211219225587794.
# [I 2022-06-16 17:28:01,434] Trial 15 finished with value: 0.20276575087289356 and parameters: {'n_estimators': 17, 'learning_rate': 0.701515914934703, 'subsample': 0.7023663664462187, 'depth': 6}. Best is trial 12 with value: 0.19211219225587794.
# [I 2022-06-16 17:28:01,694] Trial 16 finished with value: 0.19752191659812068 and parameters: {'n_estimators': 12, 'learning_rate': 0.9750078998807058, 'subsample': 0.7149829325669895, 'depth': 10}. Best is trial 12 with value: 0.19211219225587794.
# [I 2022-06-16 17:28:06,772] Trial 17 finished with value: 0.18958017270865385 and parameters: {'n_estimators': 25, 'learning_rate': 0.7204409205173123, 'subsample': 0.47633595711466614, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:11,339] Trial 18 finished with value: 0.19340655183422248 and parameters: {'n_estimators': 25, 'learning_rate': 0.5460122568104643, 'subsample': 0.5050263373230294, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:13,401] Trial 19 finished with value: 0.19364213100675187 and parameters: {'n_estimators': 22, 'learning_rate': 0.6514187978736032, 'subsample': 0.44227830769383425, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:14,142] Trial 20 finished with value: 0.1934325637961843 and parameters: {'n_estimators': 15, 'learning_rate': 0.9934416252178682, 'subsample': 0.6267162825444756, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:18,997] Trial 21 finished with value: 0.19226320141394398 and parameters: {'n_estimators': 25, 'learning_rate': 0.5484790048792874, 'subsample': 0.463271909938623, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:23,585] Trial 22 finished with value: 0.19402324813823366 and parameters: {'n_estimators': 25, 'learning_rate': 0.46964062542826407, 'subsample': 0.47399148070737684, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:24,578] Trial 23 finished with value: 0.19334377552315268 and parameters: {'n_estimators': 23, 'learning_rate': 0.6981216489214532, 'subsample': 0.4211625115039988, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:28,492] Trial 24 finished with value: 0.19345826959517914 and parameters: {'n_estimators': 20, 'learning_rate': 0.5896269032640743, 'subsample': 0.5189505480863305, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:30,629] Trial 25 finished with value: 0.19100717345570212 and parameters: {'n_estimators': 21, 'learning_rate': 0.8056596306600016, 'subsample': 0.6183788307492385, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:31,315] Trial 26 finished with value: 0.19234521016017367 and parameters: {'n_estimators': 21, 'learning_rate': 0.8912717573747402, 'subsample': 0.8139227665492559, 'depth': 12}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:32,986] Trial 27 finished with value: 0.1929839238566782 and parameters: {'n_estimators': 17, 'learning_rate': 0.7814564417819043, 'subsample': 0.6368786894349536, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:33,250] Trial 28 finished with value: 0.20069460264029215 and parameters: {'n_estimators': 20, 'learning_rate': 0.7700899417957019, 'subsample': 0.7768440074054531, 'depth': 6}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:33,755] Trial 29 finished with value: 0.19504576938095508 and parameters: {'n_estimators': 23, 'learning_rate': 0.900253814895782, 'subsample': 0.2865429975117536, 'depth': 11}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:34,159] Trial 30 finished with value: 0.19736467332873966 and parameters: {'n_estimators': 16, 'learning_rate': 0.7132244555577422, 'subsample': 0.9729447656852, 'depth': 11}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:36,753] Trial 31 finished with value: 0.19379043820179265 and parameters: {'n_estimators': 25, 'learning_rate': 0.48806608317547695, 'subsample': 0.624678970762329, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:41,458] Trial 32 finished with value: 0.19341433003671973 and parameters: {'n_estimators': 23, 'learning_rate': 0.61570906188335, 'subsample': 0.33770933136242776, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:42,633] Trial 33 finished with value: 0.19537246761438842 and parameters: {'n_estimators': 24, 'learning_rate': 0.5510903596616752, 'subsample': 0.4335913861670214, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:44,589] Trial 34 finished with value: 0.19312497532528897 and parameters: {'n_estimators': 21, 'learning_rate': 0.74527090112406, 'subsample': 0.5276733107800333, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:46,988] Trial 35 finished with value: 0.18988263637412028 and parameters: {'n_estimators': 24, 'learning_rate': 0.8376615953517359, 'subsample': 0.594418767102856, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:47,326] Trial 36 finished with value: 0.19862521729890795 and parameters: {'n_estimators': 9, 'learning_rate': 0.8203734032678422, 'subsample': 0.7682362858427361, 'depth': 12}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:48,485] Trial 37 finished with value: 0.19271359819361306 and parameters: {'n_estimators': 19, 'learning_rate': 0.9112901875083013, 'subsample': 0.5759459927544794, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:50,739] Trial 38 finished with value: 0.18990154525014538 and parameters: {'n_estimators': 21, 'learning_rate': 0.9454594629753167, 'subsample': 0.6495888682703199, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:53,036] Trial 39 finished with value: 0.1896353670178848 and parameters: {'n_estimators': 22, 'learning_rate': 0.913900378148432, 'subsample': 0.6609752903394543, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:53,409] Trial 40 finished with value: 0.1931413030721687 and parameters: {'n_estimators': 24, 'learning_rate': 0.936861960329496, 'subsample': 0.6804810468297133, 'depth': 9}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:55,382] Trial 41 finished with value: 0.19099240198553932 and parameters: {'n_estimators': 21, 'learning_rate': 0.8590656352495961, 'subsample': 0.603183403536476, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:56,120] Trial 42 finished with value: 0.19235263482775 and parameters: {'n_estimators': 22, 'learning_rate': 0.8649808152530603, 'subsample': 0.6689097397992796, 'depth': 12}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:57,342] Trial 43 finished with value: 0.19060813429662884 and parameters: {'n_estimators': 23, 'learning_rate': 0.9473687448184592, 'subsample': 0.5535225764375016, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:58,548] Trial 44 finished with value: 0.19055011354291332 and parameters: {'n_estimators': 23, 'learning_rate': 0.9609795091246802, 'subsample': 0.5533869699754168, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:28:59,216] Trial 45 finished with value: 0.19247440218462067 and parameters: {'n_estimators': 24, 'learning_rate': 0.9550426990737149, 'subsample': 0.36816729988973396, 'depth': 12}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:01,223] Trial 46 finished with value: 0.19084642074037209 and parameters: {'n_estimators': 22, 'learning_rate': 0.9057610872605923, 'subsample': 0.6575554546739297, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:02,475] Trial 47 finished with value: 0.1907968246992119 and parameters: {'n_estimators': 24, 'learning_rate': 0.9984582675586025, 'subsample': 0.49162621593725764, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:02,944] Trial 48 finished with value: 0.19503839573183931 and parameters: {'n_estimators': 19, 'learning_rate': 0.8388520133713432, 'subsample': 0.5484235680654873, 'depth': 11}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:03,054] Trial 49 finished with value: 0.240146600304471 and parameters: {'n_estimators': 5, 'learning_rate': 0.1646084130342596, 'subsample': 0.10389367709181963, 'depth': 8}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:03,320] Trial 50 finished with value: 0.1959581345382921 and parameters: {'n_estimators': 23, 'learning_rate': 0.9276906203527618, 'subsample': 0.7306423452333091, 'depth': 7}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:04,618] Trial 51 finished with value: 0.19074505812258818 and parameters: {'n_estimators': 23, 'learning_rate': 0.9602207678734362, 'subsample': 0.5675303921199731, 'depth': 13}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:06,850] Trial 52 finished with value: 0.19006081530431107 and parameters: {'n_estimators': 22, 'learning_rate': 0.8785363997824983, 'subsample': 0.5412887580973655, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:07,069] Trial 53 finished with value: 0.20372971771660744 and parameters: {'n_estimators': 25, 'learning_rate': 0.8838595903289959, 'subsample': 0.39213122914918386, 'depth': 4}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:11,324] Trial 54 finished with value: 0.18966926978685636 and parameters: {'n_estimators': 22, 'learning_rate': 0.8103694324230997, 'subsample': 0.5948590015379649, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:15,888] Trial 55 finished with value: 0.18968502518388844 and parameters: {'n_estimators': 22, 'learning_rate': 0.8080864402014444, 'subsample': 0.6020318973129369, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:20,018] Trial 56 finished with value: 0.1901803755165197 and parameters: {'n_estimators': 20, 'learning_rate': 0.7945567098721311, 'subsample': 0.5983780077299994, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:24,132] Trial 57 finished with value: 0.1919668922286583 and parameters: {'n_estimators': 21, 'learning_rate': 0.672906141674809, 'subsample': 0.740441324306414, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:26,882] Trial 58 finished with value: 0.19532548326267268 and parameters: {'n_estimators': 13, 'learning_rate': 0.7534539156171726, 'subsample': 0.6405694384776426, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:29,222] Trial 59 finished with value: 0.19040467868828514 and parameters: {'n_estimators': 24, 'learning_rate': 0.8226601629738507, 'subsample': 0.4829251281268373, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:33,449] Trial 60 finished with value: 0.19029133770051734 and parameters: {'n_estimators': 20, 'learning_rate': 0.8481105172072215, 'subsample': 0.6700334993130264, 'depth': 15}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:35,531] Trial 61 finished with value: 0.19217095258979164 and parameters: {'n_estimators': 22, 'learning_rate': 0.7433561919781267, 'subsample': 0.522971414205576, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:37,712] Trial 62 finished with value: 0.19104690054549991 and parameters: {'n_estimators': 22, 'learning_rate': 0.8671379214611941, 'subsample': 0.5866995604656418, 'depth': 14}. Best is trial 17 with value: 0.18958017270865385.
# [I 2022-06-16 17:29:42,936] Trial 63 finished with value: 0.1882545988131495 and parameters: {'n_estimators': 25, 'learning_rate': 0.7995540206326577, 'subsample': 0.6033011804038436, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:29:47,923] Trial 64 finished with value: 0.1889472558378465 and parameters: {'n_estimators': 25, 'learning_rate': 0.8016095335889489, 'subsample': 0.6017037327531903, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:29:52,932] Trial 65 finished with value: 0.190022425284251 and parameters: {'n_estimators': 25, 'learning_rate': 0.7259872351725237, 'subsample': 0.6994243552425388, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:29:57,683] Trial 66 finished with value: 0.18875511647885596 and parameters: {'n_estimators': 24, 'learning_rate': 0.7992024515915258, 'subsample': 0.6000386329125, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:02,262] Trial 67 finished with value: 0.19021641696856587 and parameters: {'n_estimators': 25, 'learning_rate': 0.6838569778033918, 'subsample': 0.4614600035379093, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:07,086] Trial 68 finished with value: 0.18908608841434826 and parameters: {'n_estimators': 24, 'learning_rate': 0.7899973184616875, 'subsample': 0.6221732392053517, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:12,318] Trial 69 finished with value: 0.18972932529770348 and parameters: {'n_estimators': 25, 'learning_rate': 0.6447557910427888, 'subsample': 0.8401188065036324, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:12,576] Trial 70 finished with value: 0.20282439779638284 and parameters: {'n_estimators': 24, 'learning_rate': 0.7724034161207429, 'subsample': 0.7490226947719588, 'depth': 4}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:17,900] Trial 71 finished with value: 0.18909261167893784 and parameters: {'n_estimators': 25, 'learning_rate': 0.8121618107854763, 'subsample': 0.61880600694227, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:22,938] Trial 72 finished with value: 0.18906135281762923 and parameters: {'n_estimators': 24, 'learning_rate': 0.7784563709481428, 'subsample': 0.6261780983478248, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:27,723] Trial 73 finished with value: 0.1897285685367725 and parameters: {'n_estimators': 25, 'learning_rate': 0.7629344572803841, 'subsample': 0.6937989016047424, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:30,180] Trial 74 finished with value: 0.19088787074279887 and parameters: {'n_estimators': 24, 'learning_rate': 0.731423765146321, 'subsample': 0.6299802932204123, 'depth': 14}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:30,366] Trial 75 finished with value: 0.2198610796826476 and parameters: {'n_estimators': 25, 'learning_rate': 0.7920716918533937, 'subsample': 0.5085520809919918, 'depth': 1}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:35,064] Trial 76 finished with value: 0.19123683590860885 and parameters: {'n_estimators': 24, 'learning_rate': 0.6716165776124272, 'subsample': 0.6190466374576231, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:37,558] Trial 77 finished with value: 0.1930531335679442 and parameters: {'n_estimators': 23, 'learning_rate': 0.5995078217793517, 'subsample': 0.5685613959433337, 'depth': 14}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:42,087] Trial 78 finished with value: 0.1953302793581623 and parameters: {'n_estimators': 25, 'learning_rate': 0.4427682269946236, 'subsample': 0.4119191825660128, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:42,996] Trial 79 finished with value: 0.1988764047389304 and parameters: {'n_estimators': 9, 'learning_rate': 0.7186082980740837, 'subsample': 0.6778165019155846, 'depth': 14}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:44,338] Trial 80 finished with value: 0.1903707377258982 and parameters: {'n_estimators': 24, 'learning_rate': 0.7864882925310178, 'subsample': 0.7140183552576265, 'depth': 13}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:49,225] Trial 81 finished with value: 0.1893264553078536 and parameters: {'n_estimators': 23, 'learning_rate': 0.8206692769241015, 'subsample': 0.6497563568620833, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:53,735] Trial 82 finished with value: 0.18968268031390173 and parameters: {'n_estimators': 23, 'learning_rate': 0.8477752648966925, 'subsample': 0.648005379205484, 'depth': 15}. Best is trial 63 with value: 0.1882545988131495.
# [I 2022-06-16 17:30:58,541] Trial 83 finished with value: 0.18770117624483854 and parameters: {'n_estimators': 24, 'learning_rate': 0.9147807920942731, 'subsample': 0.6177767377879807, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:03,413] Trial 84 finished with value: 0.18894846807675553 and parameters: {'n_estimators': 25, 'learning_rate': 0.7687535177610797, 'subsample': 0.6191477683767391, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:08,204] Trial 85 finished with value: 0.19018322405782243 and parameters: {'n_estimators': 24, 'learning_rate': 0.8205356919378194, 'subsample': 0.6183133606956167, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:09,563] Trial 86 finished with value: 0.1915959781557481 and parameters: {'n_estimators': 25, 'learning_rate': 0.698765175780938, 'subsample': 0.5769395659150772, 'depth': 13}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:11,815] Trial 87 finished with value: 0.19772496807849238 and parameters: {'n_estimators': 23, 'learning_rate': 0.3728400776777914, 'subsample': 0.6133284454594767, 'depth': 14}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:16,170] Trial 88 finished with value: 0.1895148721973605 and parameters: {'n_estimators': 24, 'learning_rate': 0.7620261573801057, 'subsample': 0.5297914980700567, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:20,668] Trial 89 finished with value: 0.18914011288008548 and parameters: {'n_estimators': 23, 'learning_rate': 0.8320765626237975, 'subsample': 0.6435319445651031, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:23,102] Trial 90 finished with value: 0.18944342322933597 and parameters: {'n_estimators': 25, 'learning_rate': 0.8835203162329819, 'subsample': 0.6822764792308247, 'depth': 14}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:27,490] Trial 91 finished with value: 0.1891272144163752 and parameters: {'n_estimators': 23, 'learning_rate': 0.8318205431909259, 'subsample': 0.6428779228323114, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:32,224] Trial 92 finished with value: 0.18819890907389494 and parameters: {'n_estimators': 24, 'learning_rate': 0.8364713719162201, 'subsample': 0.6334067405271443, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:34,716] Trial 93 finished with value: 0.1889608899020375 and parameters: {'n_estimators': 25, 'learning_rate': 0.8589522508965102, 'subsample': 0.5551272607400825, 'depth': 14}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:37,185] Trial 94 finished with value: 0.18954517259060052 and parameters: {'n_estimators': 24, 'learning_rate': 0.9211574299071574, 'subsample': 0.5572392690232152, 'depth': 14}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:41,771] Trial 95 finished with value: 0.1885848228886118 and parameters: {'n_estimators': 25, 'learning_rate': 0.8949256229643789, 'subsample': 0.58350727856936, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:44,144] Trial 96 finished with value: 0.18957569132826987 and parameters: {'n_estimators': 24, 'learning_rate': 0.8888626331627941, 'subsample': 0.5864258139835258, 'depth': 14}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:49,031] Trial 97 finished with value: 0.18895710772132215 and parameters: {'n_estimators': 25, 'learning_rate': 0.8656898048445979, 'subsample': 0.49929589706582245, 'depth': 15}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:50,234] Trial 98 finished with value: 0.19024292053109093 and parameters: {'n_estimators': 25, 'learning_rate': 0.9737766050749771, 'subsample': 0.543063602658869, 'depth': 13}. Best is trial 83 with value: 0.18770117624483854.
# [I 2022-06-16 17:31:52,746] Trial 99 finished with value: 0.1895996124111499 and parameters: {'n_estimators': 25, 'learning_rate': 0.8561705446124596, 'subsample': 0.49672448383539164, 'depth': 14}. Best is trial 83 with value: 0.18770117624483854.

# %%
best_params = {'n_estimators': 24, 'learning_rate': 0.9147807920942731, 'subsample': 0.6177767377879807, 'depth': 15}
# best_params = {'n_estimators': 20, 'learning_rate': 0.8216148051350802, 'subsample': 0.9574480991797255, 'depth': 12}
booster = CatBoostRegressor(random_seed=322, logging_level="Silent", **best_params, eval_metric="MAE", bootstrap_type="Bernoulli")\
              .fit(X_train, y_train)

y_pred = booster.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.1898641534751304

# %% [markdown]
# ## Предсказываем

# %%
data_test_features["demand"] = booster.predict(Test)
data_test_features["demand"] = np.expm1(data_test_features["demand"])

# %%
data_test_features.head()
# Out:
#    product_id  location_id  day  month  year  week_of_year  day_of_year  \
# 0       22939         1162   30     12  2019             1          364
# 1       23162         1162   30     12  2019             1          364
# 2       23163         1162   16     12  2019            51          350
# 3       23632          798   23     12  2019            52          357
# 4       23633         1347   30     12  2019             1          364
#
#    high_demand_week  high_demand_year    demand
# 0                 0                 0  0.182245
# 1                 0                 0  0.218312
# 2                 1                 0  0.176656
# 3                 1                 0  0.364685
# 4                 0                 0  0.329716

# %%
submission = pd.DataFrame(data={'id': data_test["id"], 'demand': data_test_features["demand"]})
submission.head()
# Out:
#       id    demand
# 0     16  0.182245
# 1   7867  0.218312
# 2   8667  0.176656
# 3  14835  0.364685
# 4  14959  0.329716

# %%
submission.to_csv('submission.csv', index=False)
